# %%
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import requests

# Import the API key.
from config import nytimes_api_key

# Import the datetime module from the datetime library.
import time
from datetime import datetime

# %%
query="canada"
url="https://api.nytimes.com/svc/search/v2/articlesearch.json?"
data_url=url + "q="+ query + "&api-key="+ nytimes_api_key
print(data_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=canada&api-key=6YeOqpcAHK3wvMkNm7WMl21N2HDrPMbL

# %%
data=requests.get(data_url).json()

# %%
print(data)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2022 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'abstract': 'After two and a half years, Canada is dropping its remaining restrictions, including testing and quarantine requirements, effective Oct. 1.', 'web_url': 'https://www.nytimes.com/2022/09/26/world/canada/canada-border-covid-restrictions-removed.html', 'snippet': 'After two and a half years, Canada is dropping its remaining restrictions, including testing and quarantine requirements, effective Oct. 1.', 'lead_paragraph': 'Canada announced on Monday that it would remove all remaining coronavirus entry restrictions, including testing and quarantine requirements, effective Oct. 1, ending some of the world’s longest and most stringent rules.', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-articleLarge.jpg', 'height': 400, 'width': 600, 'legacy': {'xlarge': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 400}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'popup', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-popup.jpg', 'height': 433, 'width': 650, 'legacy': {}, 'subType': 'popup', 'crop_name': 'popup'}, {'rank': 0, 'subtype': 'blog480', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-blog480.jpg', 'height': 320, 'width': 480, 'legacy': {}, 'subType': 'blog480', 'crop_name': 'blog480'}, {'rank': 0, 'subtype': 'blog533', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-blog533.jpg', 'height': 355, 'width': 533, 'legacy': {}, 'subType': 'blog533', 'crop_name': 'blog533'}, {'rank': 0, 'subtype': 'blog427', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-blog427.jpg', 'height': 285, 'width': 427, 'legacy': {}, 'subType': 'blog427', 'crop_name': 'blog427'}, {'rank': 0, 'subtype': 'tmagSF', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-tmagSF.jpg', 'height': 241, 'width': 362, 'legacy': {}, 'subType': 'tmagSF', 'crop_name': 'tmagSF'}, {'rank': 0, 'subtype': 'tmagArticle', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-tmagArticle.jpg', 'height': 395, 'width': 592, 'legacy': {}, 'subType': 'tmagArticle', 'crop_name': 'tmagArticle'}, {'rank': 0, 'subtype': 'slide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-slide.jpg', 'height': 400, 'width': 600, 'legacy': {}, 'subType': 'slide', 'crop_name': 'slide'}, {'rank': 0, 'subtype': 'jumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-jumbo.jpg', 'height': 683, 'width': 1024, 'legacy': {}, 'subType': 'jumbo', 'crop_name': 'jumbo'}, {'rank': 0, 'subtype': 'superJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-superJumbo.jpg', 'height': 1365, 'width': 2048, 'legacy': {}, 'subType': 'superJumbo', 'crop_name': 'superJumbo'}, {'rank': 0, 'subtype': 'blog225', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/09/26/multimedia/26xp-canadaborder5-1-5c9d/26xp-canadaborder5-1-5c9d-blog225.jpg', 'height': 150, 'width': 225, 'legacy': {}, 'subType': ...
