# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,2000)
lngs = np.random.uniform(-180,180,2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
import sys
# adding config_file/subfolder to the system path
sys.path.insert(0, '/Users/vikasjoshi/Desktop/Study/Python/World_Weather_Analysis')

from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7bf88b1f686751d2c44b3455e17d0618

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carnarvon
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | sobolevo
# Processing Record 4 of Set 1 | banda aceh
# Processing Record 5 of Set 1 | hambantota
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | termoli
# Processing Record 8 of Set 1 | torbay
# Processing Record 9 of Set 1 | magadan
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | price
# Processing Record 12 of Set 1 | te anau
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | mahibadhoo
# Processing Record 16 of Set 1 | tateyama
# Processing Record 17 of Set 1 | broome
# Processing Record 18 of Set 1 | coroico
# Processing Record 19 of Set 1 | alugan
# Processing Record 20 of Set 1 | vestmannaeyjar
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | mahebourg
# Processing Record 23 of Set 1 | jumla
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | faya
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 1 | san patricio
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | santa cruz de tenerife
# Processing Record 33 of Set 1 | ampanihy
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | codrington
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | aksu
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | mahina
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 1 | aripuana
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | plyussa
# Processing Record 2 of Set 2 | port lincoln
# Processing Record 3 of Set 2 | kimbe
# Processing Record 4 of Set 2 | sao joao da barra
# Processing Record 5 of Set 2 | abha
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | pedernales
# Processing Record 8 of Set 2 | altamira
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | leningradskiy
# Processing Record 11 of Set 2 | veracruz
# Processing Record 12 of Set 2 | dalinghe
# City not found. Skipping...
# Processing Record 13 of Set 2 | agva
# City not found. Skipping...
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | roebourne
# Processing Record 17 of Set 2 | gat
# Processing Record 18 of Set 2 | sotuta
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | itaituba
# Processing Record 22 of Set 2 | aswan
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | luderitz
# Processing Record 27 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 2 | maracai
# Processing Record 29 of Set 2 | bardiyah
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | banapur
# Processing Record 35 of Set 2 | esperance
# Processing Record 36 of Set 2 | oistins
# Processing Record 37 of Set 2 | jacareacanga
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | zeya
# Processing Record 40 of Set 2 | nome
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | samarai
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | vanimo
# Processing Record 45 of Set 2 | salinopolis
# Processing Record 46 of Set 2 | palmer
# Processing Record 47 of Set 2 | saldanha
# Processing Record 48 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 2 | kavieng
# Processing Record 50 of Set 2 | hay river
# Processing Record 1 of Set 3 | taman
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | jiuquan
# Processing Record 4 of Set 3 | bar harbor
# Processing Record 5 of Set 3 | busselton
# Processing Record 6 of Set 3 | beloha
# Processing Record 7 of Set 3 | half moon bay
# Processing Record 8 of Set 3 | serro
# Processing Record 9 of Set 3 | kahului
# Processing Record 10 of Set 3 | northam
# Processing Record 11 of Set 3 | nouakchott
# Processing Record 12 of Set 3 | college
# Processing Record 13 of Set 3 | san cristobal
# Processing Record 14 of Set 3 | oxford
# Processing Record 15 of Set 3 | saint anthony
# Processing Record 16 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 3 | peniche
# Processing Record 18 of Set 3 | bayan
# Processing Record 19 of Set 3 | pisco
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | marsh harbour
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | bilibino
# Processing Record 24 of Set 3 | alamos
# Processing Record 25 of Set 3 | khatanga
# Processing Record 26 of Set 3 | katsuura
# Processing Record 27 of Set 3 | cap-aux-meules
# Processing Record 28 of Set 3 | sfantu gheorghe
# Processing Record 29 of Set 3 | bud
# Processing Record 30 of Set 3 | merauke
# Processing Record 31 of Set 3 | sioux lookout
# Processing Record 32 of Set 3 | russell
# Processing Record 33 of Set 3 | requena
# Processing Record 34 of Set 3 | willmar
# Processing Record 35 of Set 3 | barrow
# Processing Record 36 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 3 | lorengau
# Processing Record 38 of Set 3 | mindelo
# Processing Record 39 of Set 3 | maragogi
# Processing Record 40 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 3 | gien
# Processing Record 42 of Set 3 | wewak
# Processing Record 43 of Set 3 | saint-georges
# Processing Record 44 of Set 3 | westport
# Processing Record 45 of Set 3 | aksarka
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | kondoa
# Processing Record 49 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 3 | cururupu
# Processing Record 1 of Set 4 | atar
# Processing Record 2 of Set 4 | cape town
# Processing Record 3 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 4 | adamas
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | vardo
# Processing Record 7 of Set 4 | cabedelo
# Processing Record 8 of Set 4 | honningsvag
# Processing Record 9 of Set 4 | taoudenni
# Processing Record 10 of Set 4 | talnakh
# Processing Record 11 of Set 4 | kiama
# Processing Record 12 of Set 4 | ottawa
# Processing Record 13 of Set 4 | lata
# Processing Record 14 of Set 4 | fortuna
# Processing Record 15 of Set 4 | lashio
# Processing Record 16 of Set 4 | santiago
# Processing Record 17 of Set 4 | green river
# Processing Record 18 of Set 4 | maningrida
# Processing Record 19 of Set 4 | hofn
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | palmerston
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | kamogawa
# Processing Record 25 of Set 4 | ballina
# Processing Record 26 of Set 4 | deva
# Processing Record 27 of Set 4 | guerrero negro
# Processing Record 28 of Set 4 | miracema do tocantins
# Processing Record 29 of Set 4 | bethel
# Processing Record 30 of Set 4 | thenzawl
# Processing Record 31 of Set 4 | riyadh
# Processing Record 32 of Set 4 | zyryanka
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | cristalina
# Processing Record 35 of Set 4 | kuznechikha
# Processing Record 36 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 4 | manali
# Processing Record 40 of Set 4 | abilene
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | puerto escondido
# Processing Record 43 of Set 4 | salacgriva
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | qaqortoq
# Processing Record 46 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 4 | zunyi
# Processing Record 48 of Set 4 | evensk
# Processing Record 49 of Set 4 | novoagansk
# Processing Record 50 of Set 4 | waipawa
# Processing Record 1 of Set 5 | severo-kurilsk
# Processing Record 2 of Set 5 | nicolas de pierola
# Processing Record 3 of Set 5 | christchurch
# Processing Record 4 of Set 5 | muli
# Processing Record 5 of Set 5 | tartki
# City not found. Skipping...
# Processing Record 6 of Set 5 | khoy
# Processing Record 7 of Set 5 | buchanan
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | chibombo
# Processing Record 11 of Set 5 | kirundo
# Processing Record 12 of Set 5 | ha
# City not found. Skipping...
# Processing Record 13 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 5 | corrales
# Processing Record 15 of Set 5 | tuatapere
# Processing Record 16 of Set 5 | avarua
# Processing Record 17 of Set 5 | komsomolskiy
# Processing Record 18 of Set 5 | coquimbo
# Processing Record 19 of Set 5 | aleksandrov gay
# Processing Record 20 of Set 5 | east london
# Processing Record 21 of Set 5 | moose factory
# Processing Record 22 of Set 5 | catania
# Processing Record 23 of Set 5 | juegang
# Processing Record 24 of Set 5 | najran
# Processing Record 25 of Set 5 | sovetskiy
# Processing Record 26 of Set 5 | noshiro
# Processing Record 27 of Set 5 | calvinia
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | dongsheng
# Processing Record 30 of Set 5 | brae
# Processing Record 31 of Set 5 | miles city
# Processing Record 32 of Set 5 | porto novo
# Processing Record 33 of Set 5 | gasa
# Processing Record 34 of Set 5 | bukachacha
# Processing Record 35 of Set 5 | prokhorovka
# Processing Record 36 of Set 5 | mar del plata
# Processing Record 37 of Set 5 | lephepe
# City not found. Skipping...
# Processing Record 38 of Set 5 | nynashamn
# Processing Record 39 of Set 5 | saint-francois
# Processing Record 40 of Set 5 | yerbogachen
# Processing Record 41 of Set 5 | ust-omchug
# Processing Record 42 of Set 5 | manaus
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | gao
# Processing Record 45 of Set 5 | fort abbas
# Processing Record 46 of Set 5 | kayankulam
# Processing Record 47 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 5 | acapulco
# Processing Record 49 of Set 5 | matamoros
# Processing Record 50 of Set 5 | sola
# Processing Record 1 of Set 6 | west bay
# Processing Record 2 of Set 6 | kununurra
# Processing Record 3 of Set 6 | manggar
# Processing Record 4 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 6 | lagoa
# Processing Record 6 of Set 6 | keti bandar
# Processing Record 7 of Set 6 | praia da vitoria
# Processing Record 8 of Set 6 | hami
# Processing Record 9 of Set 6 | cozumel
# Processing Record 10 of Set 6 | santa cruz de la palma
# Processing Record 11 of Set 6 | boke
# Processing Record 12 of Set 6 | rawah
# Processing Record 13 of Set 6 | norden
# Processing Record 14 of Set 6 | qaanaaq
# Processing Record 15 of Set 6 | berlevag
# Processing Record 16 of Set 6 | pangoa
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | port blair
# Processing Record 19 of Set 6 | mossendjo
# Processing Record 20 of Set 6 | wawa
# Processing Record 21 of Set 6 | puerto ayora
# Processing Record 22 of Set 6 | paamiut
# Processing Record 23 of Set 6 | whitecourt
# Processing Record 24 of Set 6 | chifeng
# Processing Record 25 of Set 6 | okhotsk
# Processing Record 26 of Set 6 | sur
# Processing Record 27 of Set 6 | laredo
# Processing Record 28 of Set 6 | maceio
# Processing Record 29 of Set 6 | rio gallegos
# Processing Record 30 of Set 6 | sergeyevka
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | saurimo
# Processing Record 33 of Set 6 | balykshi
# Processing Record 34 of Set 6 | pevek
# Processing Record 35 of Set 6 | hit
# Processing Record 36 of Set 6 | tchollire
# Processing Record 37 of Set 6 | trindade
# Processing Record 38 of Set 6 | ponta delgada
# Processing Record 39 of Set 6 | kavaratti
# Processing Record 40 of Set 6 | vikhorevka
# Processing Record 41 of Set 6 | udachnyy
# Processing Record 42 of Set 6 | baykit
# Processing Record 43 of Set 6 | yulara
# Processing Record 44 of Set 6 | yantal
# Processing Record 45 of Set 6 | portland
# Processing Record 46 of Set 6 | sorland
# Processing Record 47 of Set 6 | north bend
# Processing Record 48 of Set 6 | ostrovnoy
# Processing Record 49 of Set 6 | abasolo
# Processing Record 50 of Set 6 | awbari
# Processing Record 1 of Set 7 | gympie
# Processing Record 2 of Set 7 | eenhana
# Processing Record 3 of Set 7 | ugoofaaru
# Processing Record 4 of Set 7 | bryan
# Processing Record 5 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | coahuayana
# Processing Record 7 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 7 | kudahuvadhoo
# Processing Record 9 of Set 7 | ranfurly
# Processing Record 10 of Set 7 | dingle
# Processing Record 11 of Set 7 | achisay
# City not found. Skipping...
# Processing Record 12 of Set 7 | loikaw
# Processing Record 13 of Set 7 | ambilobe
# Processing Record 14 of Set 7 | rabaul
# Processing Record 15 of Set 7 | jizan
# Processing Record 16 of Set 7 | ak-dovurak
# Processing Record 17 of Set 7 | belmonte
# Processing Record 18 of Set 7 | tasiilaq
# Processing Record 19 of Set 7 | riverton
# Processing Record 20 of Set 7 | auki
# Processing Record 21 of Set 7 | san miguel
# Processing Record 22 of Set 7 | asau
# Processing Record 23 of Set 7 | lavrentiya
# Processing Record 24 of Set 7 | marsa matruh
# Processing Record 25 of Set 7 | klaksvik
# Processing Record 26 of Set 7 | mezhdurechenskiy
# Processing Record 27 of Set 7 | gbarnga
# Processing Record 28 of Set 7 | mattru
# Processing Record 29 of Set 7 | caravelas
# Processing Record 30 of Set 7 | constitucion
# Processing Record 31 of Set 7 | korla
# Processing Record 32 of Set 7 | bereda
# Processing Record 33 of Set 7 | nageshwari
# Processing Record 34 of Set 7 | flin flon
# Processing Record 35 of Set 7 | san carlos de bariloche
# Processing Record 36 of Set 7 | mugango
# Processing Record 37 of Set 7 | den helder
# Processing Record 38 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 7 | petropavl
# Processing Record 40 of Set 7 | honiara
# Processing Record 41 of Set 7 | rosarito
# Processing Record 42 of Set 7 | otaru
# Processing Record 43 of Set 7 | nantucket
# Processing Record 44 of Set 7 | mehamn
# Processing Record 45 of Set 7 | tema
# Processing Record 46 of Set 7 | zaranj
# Processing Record 47 of Set 7 | yoichi
# Processing Record 48 of Set 7 | olavarria
# Processing Record 49 of Set 7 | bandarbeyla
# Processing Record 50 of Set 7 | pangnirtung
# Processing Record 1 of Set 8 | sosnovo-ozerskoye
# Processing Record 2 of Set 8 | calama
# Processing Record 3 of Set 8 | panjab
# Processing Record 4 of Set 8 | seydi
# Processing Record 5 of Set 8 | lompoc
# Processing Record 6 of Set 8 | namibe
# Processing Record 7 of Set 8 | luang prabang
# Processing Record 8 of Set 8 | teya
# Processing Record 9 of Set 8 | camacha
# Processing Record 10 of Set 8 | pangai
# Processing Record 11 of Set 8 | victor harbor
# Processing Record 12 of Set 8 | san jeronimo
# Processing Record 13 of Set 8 | belyy yar
# Processing Record 14 of Set 8 | yaan
# Processing Record 15 of Set 8 | lebu
# Processing Record 16 of Set 8 | caicedo
# Processing Record 17 of Set 8 | sao miguel do araguaia
# Processing Record 18 of Set 8 | benghazi
# Processing Record 19 of Set 8 | chapais
# Processing Record 20 of Set 8 | gemena
# Processing Record 21 of Set 8 | ogori
# Processing Record 22 of Set 8 | we
# City not found. Skipping...
# Processing Record 23 of Set 8 | chiang rai
# Processing Record 24 of Set 8 | padang
# Processing Record 25 of Set 8 | olafsvik
# Processing Record 26 of Set 8 | goleniow
# Processing Record 27 of Set 8 | bambous virieux
# Processing Record 28 of Set 8 | anan
# Processing Record 29 of Set 8 | iturama
# Processing Record 30 of Set 8 | khandyga
# Processing Record 31 of Set 8 | sao jose da coroa grande
# Processing Record 32 of Set 8 | dobryanka
# Processing Record 33 of Set 8 | port augusta
# Processing Record 34 of Set 8 | esmeraldas
# Processing Record 35 of Set 8 | benguela
# Processing Record 36 of Set 8 | maniitsoq
# Processing Record 37 of Set 8 | karpogory
# Processing Record 38 of Set 8 | sibolga
# Processing Record 39 of Set 8 | cabo san lucas
# Processing Record 40 of Set 8 | provideniya
# Processing Record 41 of Set 8 | kisangani
# Processing Record 42 of Set 8 | oktyabrskiy
# Processing Record 43 of Set 8 | tete
# Processing Record 44 of Set 8 | akalkot
# Processing Record 45 of Set 8 | turukhansk
# Processing Record 46 of Set 8 | rorvik
# Processing Record 47 of Set 8 | tarrega
# Processing Record 48 of Set 8 | ahipara
# Processing Record 49 of Set 8 | kampene
# Processing Record 50 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 1 of Set 9 | atambua
# Processing Record 2 of Set 9 | caxito
# Processing Record 3 of Set 9 | port-gentil
# Processing Record 4 of Set 9 | the pas
# Processing Record 5 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 6 of Set 9 | preobrazheniye
# Processing Record 7 of Set 9 | saint-augustin
# Processing Record 8 of Set 9 | tekeli
# Processing Record 9 of Set 9 | zaraza
# Processing Record 10 of Set 9 | anori
# Processing Record 11 of Set 9 | coihaique
# Processing Record 12 of Set 9 | muros
# Processing Record 13 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 14 of Set 9 | nanortalik
# Processing Record 15 of Set 9 | ikot ekpene
# Processing Record 16 of Set 9 | port hardy
# Processing Record 17 of Set 9 | katherine
# Processing Record 18 of Set 9 | lazarev
# Processing Record 19 of Set 9 | west wendover
# Processing Record 20 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 9 | dillon
# Processing Record 22 of Set 9 | sambava
# Processing Record 23 of Set 9 | yuzhno-kurilsk
# Processing Record 24 of Set 9 | edd
# Processing Record 25 of Set 9 | praia
# Processing Record 26 of Set 9 | kerema
# Processing Record 27 of Set 9 | grand gaube
# Processing Record 28 of Set 9 | broken hill
# Processing Record 29 of Set 9 | rawson
# Processing Record 30 of Set 9 | rudnogorsk
# Processing Record 31 of Set 9 | balakhninskiy
# Processing Record 32 of Set 9 | vila
# Processing Record 33 of Set 9 | puri
# Processing Record 34 of Set 9 | anniston
# Processing Record 35 of Set 9 | orange
# Processing Record 36 of Set 9 | luau
# Processing Record 37 of Set 9 | santiago de cuba
# Processing Record 38 of Set 9 | nyazepetrovsk
# Processing Record 39 of Set 9 | touros
# Processing Record 40 of Set 9 | doctor arroyo
# Processing Record 41 of Set 9 | eureka
# Processing Record 42 of Set 9 | laguna
# Processing Record 43 of Set 9 | paucartambo
# City not found. Skipping...
# Processing Record 44 of Set 9 | boende
# Processing Record 45 of Set 9 | zlitan
# Processing Record 46 of Set 9 | el fuerte
# Processing Record 47 of Set 9 | siniscola
# Processing Record 48 of Set 9 | aberdeen
# Processing Record 49 of Set 9 | senneterre
# Processing Record 50 of Set 9 | poum
# Processing Record 1 of Set 10 | union city
# Processing Record 2 of Set 10 | vilhena
# Processing Record 3 of Set 10 | gimli
# Processing Record 4 of Set 10 | nikolskoye
# Processing Record 5 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 10 | mordovo
# Processing Record 7 of Set 10 | airai
# Processing Record 8 of Set 10 | bendigo
# Processing Record 9 of Set 10 | tignere
# Processing Record 10 of Set 10 | jalu
# Processing Record 11 of Set 10 | myaundzha
# Processing Record 12 of Set 10 | sabang
# Processing Record 13 of Set 10 | dunedin
# Processing Record 14 of Set 10 | vredendal
# Processing Record 15 of Set 10 | awjilah
# Processing Record 16 of Set 10 | moree
# Processing Record 17 of Set 10 | plettenberg bay
# Processing Record 18 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 19 of Set 10 | hasaki
# Processing Record 20 of Set 10 | kruisfontein
# Processing Record 21 of Set 10 | brasilia
# Processing Record 22 of Set 10 | hamilton
# Processing Record 23 of Set 10 | barinas
# Processing Record 24 of Set 10 | severodvinsk
# Processing Record 25 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 26 of Set 10 | general roca
# Processing Record 27 of Set 10 | harper
# Processing Record 28 of Set 10 | develi
# Processing Record 29 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 10 | longkou
# Processing Record 31 of Set 10 | kalavai
# Processing Record 32 of Set 10 | ketchikan
# Processing Record 33 of Set 10 | bathsheba
# Processing Record 34 of Set 10 | vytegra
# Processing Record 35 of Set 10 | karratha
# Processing Record 36 of Set 10 | la rioja
# Processing Record 37 of Set 10 | monoharpur
# Processing Record 38 of Set 10 | charters towers
# Processing Record 39 of Set 10 | discovery bay
# Processing Record 40 of Set 10 | chioggia
# Processing Record 41 of Set 10 | laiagam
# City not found. Skipping...
# Processing Record 42 of Set 10 | tecoanapa
# Processing Record 43 of Set 10 | ikalamavony
# Processing Record 44 of Set 10 | bara
# Processing Record 45 of Set 10 | puerto cabezas
# Processing Record 46 of Set 10 | kodinsk
# Processing Record 47 of Set 10 | buala
# Processing Record 48 of Set 10 | tukrah
# Processing Record 49 of Set 10 | puerto ayacucho
# Processing Record 50 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 11 | nacogdoches
# Processing Record 2 of Set 11 | caraballeda
# Processing Record 3 of Set 11 | tuy hoa
# Processing Record 4 of Set 11 | yanam
# Processing Record 5 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 11 | sterling
# Processing Record 7 of Set 11 | lebanon
# Processing Record 8 of Set 11 | buraydah
# Processing Record 9 of Set 11 | cilegon
# Processing Record 10 of Set 11 | ixtapa
# Processing Record 11 of Set 11 | san juan
# Processing Record 12 of Set 11 | tura
# Processing Record 13 of Set 11 | luwuk
# Processing Record 14 of Set 11 | kem
# Processing Record 15 of Set 11 | kidal
# Processing Record 16 of Set 11 | garowe
# Processing Record 17 of Set 11 | namatanai
# Processing Record 18 of Set 11 | chumikan
# Processing Record 19 of Set 11 | tlalnepantla
# Processing Record 20 of Set 11 | mirabad
# Processing Record 21 of Set 11 | traralgon
# Processing Record 22 of Set 11 | maykor
# Processing Record 23 of Set 11 | erenhot
# Processing Record 24 of Set 11 | san jose
# Processing Record 25 of Set 11 | kemijarvi
# Processing Record 26 of Set 11 | husavik
# Processing Record 27 of Set 11 | dubti
# Processing Record 28 of Set 11 | nouadhibou
# Processing Record 29 of Set 11 | veraval
# Processing Record 30 of Set 11 | ahuimanu
# Processing Record 31 of Set 11 | nemuro
# Processing Record 32 of Set 11 | abaza
# Processing Record 33 of Set 11 | tavda
# Processing Record 34 of Set 11 | haines junction
# Processing Record 35 of Set 11 | vila velha
# Processing Record 36 of Set 11 | teul
# City not found. Skipping...
# Processing Record 37 of Set 11 | erzin
# Processing Record 38 of Set 11 | diego de almagro
# Processing Record 39 of Set 11 | lermontovka
# Processing Record 40 of Set 11 | alofi
# Processing Record 41 of Set 11 | taunsa
# Processing Record 42 of Set 11 | salalah
# Processing Record 43 of Set 11 | macusani
# Processing Record 44 of Set 11 | quelimane
# Processing Record 45 of Set 11 | otacilio costa
# Processing Record 46 of Set 11 | gonbad-e qabus
# Processing Record 47 of Set 11 | clyde river
# Processing Record 48 of Set 11 | zhigansk
# Processing Record 49 of Set 11 | walvis bay
# Processing Record 50 of Set 11 | grindavik
# Processing Record 1 of Set 12 | letlhakane
# Processing Record 2 of Set 12 | jalingo
# Processing Record 3 of Set 12 | gizeh
# Processing Record 4 of Set 12 | mackay
# Processing Record 5 of Set 12 | pierre
# Processing Record 6 of Set 12 | dzhebariki-khaya
# Processing Record 7 of Set 12 | matagami
# Processing Record 8 of Set 12 | menongue
# Processing Record 9 of Set 12 | vavuniya
# Processing Record 10 of Set 12 | catuday
# Processing Record 11 of Set 12 | khash
# Processing Record 12 of Set 12 | kaitangata
# Processing Record 13 of Set 12 | miranda
# Processing Record 14 of Set 12 | tiznit
# Processing Record 15 of Set 12 | escanaba
# Processing Record 16 of Set 12 | santa quiteria
# Processing Record 17 of Set 12 | gorontalo
# Processing Record 18 of Set 12 | kenai
# Processing Record 19 of Set 12 | springbok
# Processing Record 20 of Set 12 | mildura
# Processing Record 21 of Set 12 | carbonear
# Processing Record 22 of Set 12 | bonthe
# Processing Record 23 of Set 12 | rajauri
# Processing Record 24 of Set 12 | indramayu
# Processing Record 25 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 12 | hervey bay
# Processing Record 27 of Set 12 | tall kayf
# Processing Record 28 of Set 12 | barranca
# Processing Record 29 of Set 12 | bambanglipuro
# Processing Record 30 of Set 12 | slave lake
# Processing Record 31 of Set 12 | vostok
# Processing Record 32 of Set 12 | srivardhan
# Processing Record 33 of Set 12 | kwekwe
# Processing Record 34 of Set 12 | bontang
# Processing Record 35 of Set 12 | darhan
# Processing Record 36 of Set 12 | henties bay
# Processing Record 37 of Set 12 | conceicao do araguaia
# Processing Record 38 of Set 12 | cayenne
# Processing Record 39 of Set 12 | pimentel
# Processing Record 40 of Set 12 | lasa
# Processing Record 41 of Set 12 | kuito
# Processing Record 42 of Set 12 | zhuhai
# Processing Record 43 of Set 12 | carinhanha
# Processing Record 44 of Set 12 | solnechnyy
# Processing Record 45 of Set 12 | venustiano carranza
# Processing Record 46 of Set 12 | maputo
# Processing Record 47 of Set 12 | mercedes
# Processing Record 48 of Set 12 | nuevo progreso
# Processing Record 49 of Set 12 | umm lajj
# Processing Record 50 of Set 12 | bien hoa
# Processing Record 1 of Set 13 | morondava
# Processing Record 2 of Set 13 | guanica
# Processing Record 3 of Set 13 | oskarshamn
# Processing Record 4 of Set 13 | terra santa
# Processing Record 5 of Set 13 | lucea
# Processing Record 6 of Set 13 | mananara
# Processing Record 7 of Set 13 | leshukonskoye
# Processing Record 8 of Set 13 | andrews
# Processing Record 9 of Set 13 | tezu
# Processing Record 10 of Set 13 | puerto madryn
# Processing Record 11 of Set 13 | chernaya kholunitsa
# Processing Record 12 of Set 13 | guatire
# Processing Record 13 of Set 13 | hirara
# Processing Record 14 of Set 13 | tomatlan
# Processing Record 15 of Set 13 | thohoyandou
# Processing Record 16 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 13 | pekan
# Processing Record 18 of Set 13 | sakai
# Processing Record 19 of Set 13 | filadelfia
# Processing Record 20 of Set 13 | myitkyina
# Processing Record 21 of Set 13 | comodoro rivadavia
# Processing Record 22 of Set 13 | melilla
# Processing Record 23 of Set 13 | novomykolayivka
# Processing Record 24 of Set 13 | mananjary
# Processing Record 25 of Set 13 | meadville
# Processing Record 26 of Set 13 | malinyi
# Processing Record 27 of Set 13 | narsaq
# Processing Record 28 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 29 of Set 13 | vila franca do campo
# Processing Record 30 of Set 13 | coruripe
# Processing Record 31 of Set 13 | san quintin
# Processing Record 32 of Set 13 | labuhan
# Processing Record 33 of Set 13 | nishihara
# Processing Record 34 of Set 13 | metro
# Processing Record 35 of Set 13 | san antonio
# Processing Record 36 of Set 13 | acarau
# Processing Record 37 of Set 13 | sistranda
# Processing Record 38 of Set 13 | deputatskiy
# Processing Record 39 of Set 13 | dortyol
# Processing Record 40 of Set 13 | baiyin
# Processing Record 41 of Set 13 | havre-saint-pierre
# Processing Record 42 of Set 13 | lac-megantic
# Processing Record 43 of Set 13 | villefranche-de-rouergue
# Processing Record 44 of Set 13 | svetlyy
# Processing Record 45 of Set 13 | tessalit
# Processing Record 46 of Set 13 | zhuanghe
# Processing Record 47 of Set 13 | sao filipe
# Processing Record 48 of Set 13 | orsha
# Processing Record 49 of Set 13 | barra patuca
# Processing Record 50 of Set 13 | port stanley
# Processing Record 1 of Set 14 | nalut
# Processing Record 2 of Set 14 | shingu
# Processing Record 3 of Set 14 | ginir
# Processing Record 4 of Set 14 | batemans bay
# Processing Record 5 of Set 14 | moron
# Processing Record 6 of Set 14 | naryan-mar
# Processing Record 7 of Set 14 | fairbanks
# Processing Record 8 of Set 14 | fethiye
# Processing Record 9 of Set 14 | boueni
# Processing Record 10 of Set 14 | varzea da palma
# Processing Record 11 of Set 14 | lima
# Processing Record 12 of Set 14 | piet retief
# Processing Record 13 of Set 14 | hokitika
# Processing Record 14 of Set 14 | verkh-usugli
# Processing Record 15 of Set 14 | sheoganj
# Processing Record 16 of Set 14 | nicolas bravo
# Processing Record 17 of Set 14 | nam som
# Processing Record 18 of Set 14 | alexandria
# Processing Record 19 of Set 14 | yamada
# Processing Record 20 of Set 14 | iranshahr
# Processing Record 21 of Set 14 | aklavik
# Processing Record 22 of Set 14 | fort collins
# Processing Record 23 of Set 14 | balabac
# Processing Record 24 of Set 14 | cravo norte
# Processing Record 25 of Set 14 | leh
# Processing Record 26 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 14 | duluth
# Processing Record 28 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 29 of Set 14 | soyo
# Processing Record 30 of Set 14 | goderich
# Processing Record 31 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 14 | homer
# Processing Record 33 of Set 14 | bubaque
# Processing Record 34 of Set 14 | mackenzie
# Processing Record 35 of Set 14 | eberbach
# Processing Record 36 of Set 14 | rehoboth
# Processing Record 37 of Set 14 | spring valley
# Processing Record 38 of Set 14 | jonkoping
# Processing Record 39 of Set 14 | vazante
# Processing Record 40 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 41 of Set 14 | steamboat springs
# Processing Record 42 of Set 14 | santa rosa
# Processing Record 43 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 14 | roma
# Processing Record 46 of Set 14 | santa maria del oro
# Processing Record 47 of Set 14 | chervone
# Processing Record 48 of Set 14 | laje
# Processing Record 49 of Set 14 | chaman
# Processing Record 50 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 15 | atlantic city
# Processing Record 2 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 15 | byron bay
# Processing Record 4 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 5 of Set 15 | salvador
# Processing Record 6 of Set 15 | uzhur-4
# City not found. Skipping...
# Processing Record 7 of Set 15 | yar-sale
# Processing Record 8 of Set 15 | douentza
# Processing Record 9 of Set 15 | manchester
# Processing Record 10 of Set 15 | vernon
# Processing Record 11 of Set 15 | wattegama
# Processing Record 12 of Set 15 | la ronge
# Processing Record 13 of Set 15 | seoul
# Processing Record 14 of Set 15 | trelew
# Processing Record 15 of Set 15 | gigmoto
# Processing Record 16 of Set 15 | shelburne
# Processing Record 17 of Set 15 | izhma
# Processing Record 18 of Set 15 | port shepstone
# Processing Record 19 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 15 | avera
# Processing Record 21 of Set 15 | waddan
# Processing Record 22 of Set 15 | bima
# Processing Record 23 of Set 15 | geraldton
# Processing Record 24 of Set 15 | bilma
# Processing Record 25 of Set 15 | mayor pablo lagerenza
# Processing Record 26 of Set 15 | nizhniy baskunchak
# Processing Record 27 of Set 15 | puerto quijarro
# Processing Record 28 of Set 15 | ryabovo
# Processing Record 29 of Set 15 | bairiki
# Processing Record 30 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 31 of Set 15 | isangel
# Processing Record 32 of Set 15 | taitung
# Processing Record 33 of Set 15 | robstown
# Processing Record 34 of Set 15 | norrkoping
# Processing Record 35 of Set 15 | warrington
# Processing Record 36 of Set 15 | along
# Processing Record 37 of Set 15 | bosaso
# Processing Record 38 of Set 15 | kalmunai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 678

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Carnarvon -24.8667  113.6333     66.51        74           0
# 1      Souillac -20.5167   57.5167     71.98        68          75
# 2      Sobolevo  54.4299   31.8996     46.96        86         100
# 3    Banda Aceh   5.5577   95.3222     79.63        79         100
# 4    Hambantota   6.1241   81.1185     79.14        89          40
# 5  Longyearbyen  78.2186   15.6401     35.44        93          75
# 6       Termoli  41.9888   14.9895     65.79        73           5
# 7        Torbay  47.6666  -52.7314     64.58        55          75
# 8       Magadan  59.5667  150.8000     32.25        59         100
# 9     Hithadhoo  -0.6000   73.0833     81.61        72          99
#
#    Wind Speed Country Current Description
# 0       19.53      AU           clear sky
# 1       14.97      MU       broken clouds
# 2       14.99      RU     overcast clouds
# 3        9.93      ID     overcast clouds
# 4       10.36      LK    scattered clouds
# 5        4.61      SJ       broken clouds
# 6        5.55      IT           clear sky
# 7       19.57      CA       broken clouds
# 8        7.81      RU     overcast clouds
# 9       13.33      MV     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:

# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Carnarvon      AU -24.8667  113.6333     66.51        74           0
# 1      Souillac      MU -20.5167   57.5167     71.98        68          75
# 2      Sobolevo      RU  54.4299   31.8996     46.96        86         100
# 3    Banda Aceh      ID   5.5577   95.3222     79.63        79         100
# 4    Hambantota      LK   6.1241   81.1185     79.14        89          40
# 5  Longyearbyen      SJ  78.2186   15.6401     35.44        93          75
# 6       Termoli      IT  41.9888   14.9895     65.79        73           5
# 7        Torbay      CA  47.6666  -52.7314     64.58        55          75
# 8       Magadan      RU  59.5667  150.8000     32.25        59         100
# 9     Hithadhoo      MV  -0.6000   73.0833     81.61        72          99
#
#    Wind Speed Current Description
# 0       19.53           clear sky
# 1       14.97       broken clouds
# 2       14.99     overcast clouds
# 3        9.93     overcast clouds
# 4       10.36    scattered clouds
# 5        4.61       broken clouds
# 6        5.55           clear sky
# 7       19.57       broken clouds
# 8        7.81     overcast clouds
# 9       13.33     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
